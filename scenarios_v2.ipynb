# %%
import models
import constants
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
folder = './data/scenarios/'

# %%
test_scenario_rectangular_peak = pd.read_csv(folder+'00200_rectangular_pulse_210lux.csv', sep=",", decimal=".",header=0,names=['hours', 'irradiance_mel'])
test_scenario_rectangular_bursts = pd.read_csv(folder+'19437_rectangular_bursts_200lux_burst2220lux.csv', sep=",", decimal=".",header=0,names=['hours', 'irradiance_mel'])
test_scenario_rectangular_bursts

plt.plot(test_scenario_rectangular_bursts['hours'], test_scenario_rectangular_bursts['irradiance_mel'])

# %%
from datetime import datetime, timedelta
from scipy.interpolate import interp1d

def generate_time_points(start_time="07:30", end_time="17:00", interval_minutes=6):
    """Generate time points between start and end times at given interval."""
    fmt = "%H:%M"
    start = datetime.strptime(start_time, fmt)
    end = datetime.strptime(end_time, fmt)

    time_points = []
    current = start
    while current <= end:
        time_points.append(current.strftime(fmt))
        current += timedelta(minutes=interval_minutes)

    return time_points

def daytime_pattern(time_points, csv_data=None):
    """Generate a pattern of light exposure throughout the day."""
    if csv_data is None:
        # Read the daylight intensity curve from CSV if not provided
        daytime_df = pd.read_csv('./data/daytime_irradiance_curve.csv')
        csv_hours = daytime_df['time'].values
        csv_irradiance = daytime_df['irradiance'].values
    else:
        # Unpack the provided data
        csv_hours, csv_irradiance = csv_data

    # Convert time_points to datetime objects for interpolation
    time_dt = [datetime.strptime(t, '%H:%M') for t in time_points]
    time_decimals = [(t.hour + t.minute/60) for t in time_dt]

    # Create interpolation function
    interpolator = interp1d(csv_hours, csv_irradiance, kind='cubic', bounds_error=False, 
                            fill_value=(csv_irradiance[0], csv_irradiance[-1]))

    # Get relative intensity values from interpolation
    irradiance = interpolator(time_decimals) / constants.CONVERSION_FACTOR

    return irradiance.tolist()

time_points = generate_time_points(start_time="00:00", end_time="23:59", interval_minutes=1)
irradiance = daytime_pattern(time_points) + daytime_pattern(time_points) 
len(irradiance)
# Out:
# 2880

# %%
import os
import pickle
import time
import pandas as pd
from tqdm.notebook import tqdm

# Dictionary to store results
scenario_results = {}

# Create a timestamp for the filename
timestamp = time.strftime("%Y%m%d-%H%M%S")
output_filename = f"scenario_results_{timestamp}.pkl"

# Get all CSV files in the folder
csv_files = [f for f in os.listdir(folder) if f.endswith('.csv')]

# filter for specific scenarios
csv_files = [f for f in csv_files if 'rectangular' in f]
csv_files
# Out:
# ['21531_rectangular_bursts_220lux_burst4140lux.csv',
#  '21538_rectangular_bursts_220lux_burst4210lux.csv',
#  '03192_rectangular_pulse_3202lux.csv',
#  '19922_rectangular_bursts_200lux_burst7070lux.csv',
#  '21076_rectangular_bursts_210lux_burst9100lux.csv',
#  '01413_rectangular_pulse_1423lux.csv',
#  '08285_rectangular_bursts_80lux_burst4820lux.csv',
#  '07376_rectangular_bursts_70lux_burst5240lux.csv',
#  '06104_rectangular_bursts_60lux_burst2030lux.csv',
#  '02007_rectangular_pulse_2017lux.csv',
#  '04111_rectangular_pulse_4121lux.csv',
#  '11550_rectangular_bursts_110lux_burst8940lux.csv',
#  '11588_rectangular_bursts_110lux_burst9320lux.csv',
#  '10260_rectangular_bursts_100lux_burst5550lux.csv',
#  '05550_rectangular_bursts_50lux_burst6000lux.csv',
#  '03841_rectangular_pulse_3851lux.csv',
#  '11059_rectangular_bursts_110lux_burst4030lux.csv',
#  '15912_rectangular_bursts_160lux_burst5010lux.csv',
#  '24249_rectangular_bursts_250lux_burst2790lux.csv',
#  '16320_rectangular_bursts_160lux_burst9090lux.csv',
#  '08903_rectangular_bursts_90lux_burst1490lux.csv',
#  '23926_rectangular_bursts_240lux_burst9070lux.csv',
#  '09989_rectangular_bursts_100lux_burst2840lux.csv',
#  '02939_rectangular_pulse_2949lux.csv',
#  '19874_rectangular_bursts_200lux_burst6590lux.csv',
#  '01112_rectangular_pulse_1122lux.csv',
#  '06927_rectangular_bursts_70lux_burst750lux.csv',
#  '04410_rectangular_pulse_4420lux.csv',
#  '02506_rectangular_pulse_2516lux.csv',
#  '00379_rectangular_pulse_389lux.csv',
#  '07203_rectangular_bursts_70lux_burst3510lux.csv',
#  '17622_rectangular_bursts_180lux_burst3090lux.csv',
#  '08059_rectangular_bursts_80lux_burst2560lux.csv',
#  '20230_rectangular_bursts_210lux_burst640lux.csv',
#  '04993_rectangular_pulse_5003lux.csv',
#  '21205_rectangular_bursts_220lux_burst880lux.csv',
#  '22599_rectangular_bursts_230lux_burst5310lux.csv',
#  '16690_rectangular_bursts_170lux_burst3280lux.csv',
#  '07265_rectangular_bursts_70lux_burst4130lux.csv',
#  '14050_rectangular_bursts_140lux_burst5410lux.csv',
#  '21634_rectangular_bursts_220lux_burst5170lux.csv',
#  '23274_rectangular_bursts_240lux_burst2550lux.csv',
#  '22890_rectangular_bursts_230lux_burst8220lux.csv',
#  '09063_rectangular_bursts_90lux_burst3090lux.csv',
#  '13915_rectangular_bursts_140lux_burst4060lux.csv',
#  '03243_rectangular_pulse_3253lux.csv',
#  '09721_rectangular_bursts_90lux_burst9670lux.csv',
#  '09148_rectangular_bursts_90lux_burst3940lux.csv',
#  '20526_rectangular_bursts_210lux_burst3600lux.csv',
#  '21080_rectangular_bursts_210lux_burst9140lux.csv',
#  '12433_rectangular_bursts_120lux_burst8260lux.csv',
#  '00917_rectangular_pulse_927lux.csv',
#  '14194_rectangular_bursts_140lux_burst6850lux.csv',
#  '15905_rectangular_bursts_160lux_burst4940lux.csv',
#  '16495_rectangular_bursts_170lux_burst1330lux.csv',
#  '19905_rectangular_bursts_200lux_burst6900lux.csv',
#  '09446_rectangular_bursts_90lux_burst6920lux.csv',
#  '00850_rectangular_pulse_860lux.csv',
#  '02083_rectangular_pulse_2093lux.csv',
#  '18559_rectangular_bursts_190lux_burst2950lux.csv',
#  '06246_rectangular_bursts_60lux_burst3450lux.csv',
#  '12103_rectangular_bursts_120lux_burst4960lux.csv',
#  '23805_rectangular_bursts_240lux_burst7860lux.csv',
#  '17891_rectangular_bursts_180lux_burst5780lux.csv',
#  '21648_rectangular_bursts_220lux_burst5310lux.csv',
#  '07641_rectangular_bursts_70lux_burst7890lux.csv',
#  '16952_rectangular_bursts_170lux_burst5900lux.csv',
#  '21061_rectangular_bursts_210lux_burst8950lux.csv',
#  '18097_rectangular_bursts_180lux_burst7840lux.csv',
#  '07233_rectangular_bursts_70lux_burst3810lux.csv',
#  '22463_rectangular_bursts_230lux_burst3950lux.csv',
#  '00800_rectangular_pulse_810lux.csv',
#  '03742_rectangular_pulse_3752lux.csv',
#  '09729_rectangular_bursts_90lux_burst9750lux.csv',
#  '09140_rectangular_bursts_90lux_burst3860lux.csv',
#  '08167_rectangular_bursts_80lux_burst3640lux.csv',
#  '02582_rectangular_pulse_2592lux.csv',
#  '19337_rectangular_bursts_200lux_burst1220lux.csv',
#  '00947_rectangular_pulse_957lux.csv',
#  '12108_rectangular_bursts_120lux_burst5010lux.csv',
#  '14687_rectangular_bursts_150lux_burst2270lux.csv',
#  '04658_rectangular_pulse_4668lux.csv',
#  '10728_rectangular_bursts_110lux_burst720lux.csv',
#  '06606_rectangular_bursts_60lux_burst7050lux.csv',
#  '17492_rectangular_bursts_180lux_burst1790lux.csv',
#  '23406_rectangular_bursts_240lux_burst3870lux.csv',
#  '23553_rectangular_bursts_240lux_burst5340lux.csv',
#  '17756_rectangular_bursts_180lux_burst4430lux.csv',
#  '10476_rectangular_bursts_100lux_burst7710lux.csv',
#  '20085_rectangular_bursts_200lux_burst8700lux.csv',
#  '00307_rectangular_pulse_317lux.csv',
#  '20608_rectangular_bursts_210lux_burst4420lux.csv',
#  '01865_rectangular_pulse_1875lux.csv',
#  '00240_rectangular_pulse_250lux.csv',
#  '24424_rectangular_bursts_250lux_burst4540lux.csv',
#  '01470_rectangular_pulse_1480lux.csv',
#  '24783_rectangular_bursts_250lux_burst8130lux.csv',
#  '16713_rectangular_bursts_170lux_burst3510lux.csv',
#  '12024_rectangular_bursts_120lux_burst4170lux.csv',
#  '05181_rectangular_bursts_50lux_burst2310lux.csv',
#  '09907_rectangular_bursts_100lux_burst2020lux.csv',
#  '22500_rectangular_bursts_230lux_burst4320lux.csv',
#  '22047_rectangular_bursts_220lux_burst9300lux.csv',
#  '04172_rectangular_pulse_4182lux.csv',
#  '07740_rectangular_bursts_70lux_burst8880lux.csv',
#  '03337_rectangular_pulse_3347lux.csv',
#  '15311_rectangular_bursts_150lux_burst8510lux.csv',
#  '16830_rectangular_bursts_170lux_burst4680lux.csv',
#  '20056_rectangular_bursts_200lux_burst8410lux.csv',
#  '17785_rectangular_bursts_180lux_burst4720lux.csv',
#  '10572_rectangular_bursts_100lux_burst8670lux.csv',
#  '00189_rectangular_pulse_199lux.csv',
#  '12347_rectangular_bursts_120lux_burst7400lux.csv',
#  '18228_rectangular_bursts_180lux_burst9150lux.csv',
#  '21240_rectangular_bursts_220lux_burst1230lux.csv',
#  '05843_rectangular_bursts_50lux_burst8930lux.csv',
#  '00210_rectangular_pulse_220lux.csv',
#  '14664_rectangular_bursts_150lux_burst2040lux.csv',
#  '10034_rectangular_bursts_100lux_burst3290lux.csv',
#  '11721_rectangular_bursts_120lux_burst1140lux.csv',
#  '04359_rectangular_pulse_4369lux.csv',
#  '17499_rectangular_bursts_180lux_burst1860lux.csv',
#  '21944_rectangular_bursts_220lux_burst8270lux.csv',
#  '11728_rectangular_bursts_120lux_burst1210lux.csv',
#  '08886_rectangular_bursts_90lux_burst1320lux.csv',
#  '17384_rectangular_bursts_180lux_burst710lux.csv',
#  '01171_rectangular_pulse_1181lux.csv',
#  '19683_rectangular_bursts_200lux_burst4680lux.csv',
#  '08527_rectangular_bursts_80lux_burst7240lux.csv',
#  '00357_rectangular_pulse_367lux.csv',
#  '15057_rectangular_bursts_150lux_burst5970lux.csv',
#  '03636_rectangular_pulse_3646lux.csv',
#  '22000_rectangular_bursts_220lux_burst8830lux.csv',
#  '13380_rectangular_bursts_130lux_burst8220lux.csv',
#  '09327_rectangular_bursts_90lux_burst5730lux.csv',
#  '18354_rectangular_bursts_190lux_burst900lux.csv',
#  '11115_rectangular_bursts_110lux_burst4590lux.csv',
#  '19506_rectangular_bursts_200lux_burst2910lux.csv',
#  '12862_rectangular_bursts_130lux_burst3040lux.csv',
#  '04473_rectangular_pulse_4483lux.csv',
#  '07121_rectangular_bursts_70lux_burst2690lux.csv',
#  '12979_rectangular_bursts_130lux_burst4210lux.csv',
#  '24656_rectangular_bursts_250lux_burst6860lux.csv',
#  '07475_rectangular_bursts_70lux_burst6230lux.csv',
#  '22191_rectangular_bursts_230lux_burst1230lux.csv',
#  '21713_rectangular_bursts_220lux_burst5960lux.csv',
#  '17266_rectangular_bursts_170lux_burst9040lux.csv',
#  '04866_rectangular_pulse_4876lux.csv',
#  '21781_rectangular_bursts_220lux_burst6640lux.csv',
#  '20631_rectangular_bursts_210lux_burst4650lux.csv',
#  '06301_rectangular_bursts_60lux_burst4000lux.csv',
#  '05291_rectangular_bursts_50lux_burst3410lux.csv',
#  '24203_rectangular_bursts_250lux_burst2330lux.csv',
#  '06319_rectangular_bursts_60lux_burst4180lux.csv',
#  '01267_rectangular_pulse_1277lux.csv',
#  '24671_rectangular_bursts_250lux_burst7010lux.csv',
#  '10909_rectangular_bursts_110lux_burst2530lux.csv',
#  '20939_rectangular_bursts_210lux_burst7730lux.csv',
#  '06544_rectangular_bursts_60lux_burst6430lux.csv',
#  '04765_rectangular_pulse_4775lux.csv',
#  '22247_rectangular_bursts_230lux_burst1790lux.csv',
#  '01958_rectangular_pulse_1968lux.csv',
#  '11682_rectangular_bursts_120lux_burst750lux.csv',
#  '05344_rectangular_bursts_50lux_burst3940lux.csv',
#  '13889_rectangular_bursts_140lux_burst3800lux.csv',
#  '10557_rectangular_bursts_100lux_burst8520lux.csv',
#  '24319_rectangular_bursts_250lux_burst3490lux.csv',
#  '15842_rectangular_bursts_160lux_burst4310lux.csv',
#  '21186_rectangular_bursts_220lux_burst690lux.csv',
#  '11997_rectangular_bursts_120lux_burst3900lux.csv',
#  '10480_rectangular_bursts_100lux_burst7750lux.csv',
#  '05997_rectangular_bursts_60lux_burst960lux.csv',
#  '03935_rectangular_pulse_3945lux.csv',
#  '08419_rectangular_bursts_80lux_burst6160lux.csv',
#  '16736_rectangular_bursts_170lux_burst3740lux.csv',
#  '17084_rectangular_bursts_170lux_burst7220lux.csv',
#  '07566_rectangular_bursts_70lux_burst7140lux.csv',
#  '21777_rectangular_bursts_220lux_burst6600lux.csv',
#  '19117_rectangular_bursts_190lux_burst8530lux.csv',
#  '13613_rectangular_bursts_140lux_burst1040lux.csv',
#  '10742_rectangular_bursts_110lux_burst860lux.csv',
#  '01766_rectangular_pulse_1776lux.csv',
#  '19521_rectangular_bursts_200lux_burst3060lux.csv',
#  '10815_rectangular_bursts_110lux_burst1590lux.csv',
#  '13162_rectangular_bursts_130lux_burst6040lux.csv',
#  '18824_rectangular_bursts_190lux_burst5600lux.csv',
#  '24692_rectangular_bursts_250lux_burst7220lux.csv',
#  '06807_rectangular_bursts_60lux_burst9060lux.csv',
#  '17814_rectangular_bursts_180lux_burst5010lux.csv',
#  '00051_rectangular_pulse_61lux.csv',
#  '10930_rectangular_bursts_110lux_burst2740lux.csv',
#  '11976_rectangular_bursts_120lux_burst3690lux.csv',
#  '04264_rectangular_pulse_4274lux.csv',
#  '15334_rectangular_bursts_150lux_burst8740lux.csv',
#  '15511_rectangular_bursts_160lux_burst1000lux.csv',
#  '18864_rectangular_bursts_190lux_burst6000lux.csv',
#  '00764_rectangular_pulse_774lux.csv',
#  '12690_rectangular_bursts_130lux_burst1320lux.csv',
#  '13122_rectangular_bursts_130lux_burst5640lux.csv',
#  '21651_rectangular_bursts_220lux_burst5340lux.csv',
#  '00099_rectangular_pulse_109lux.csv',
#  '03273_rectangular_pulse_3283lux.csv',
#  '04036_rectangular_pulse_4046lux.csv',
#  '02620_rectangular_pulse_2630lux.csv',
#  '00623_rectangular_pulse_633lux.csv',
#  '08343_rectangular_bursts_80lux_burst5400lux.csv',
#  '01534_rectangular_pulse_1544lux.csv',
#  '21073_rectangular_bursts_210lux_burst9070lux.csv',
#  '06217_rectangular_bursts_60lux_burst3160lux.csv',
#  '11451_rectangular_bursts_110lux_burst7950lux.csv',
#  '14898_rectangular_bursts_150lux_burst4380lux.csv',
#  '12111_rectangular_bursts_120lux_burst5040lux.csv',
#  '03559_rectangular_pulse_3569lux.csv',
#  '19327_rectangular_bursts_200lux_burst1120lux.csv',
#  '06565_rectangular_bursts_60lux_burst6640lux.csv',
#  '23142_rectangular_bursts_240lux_burst1230lux.csv',
#  '08603_rectangular_bursts_80lux_burst8000lux.csv',
#  '16661_rectangular_bursts_170lux_burst2990lux.csv',
#  '05631_rectangular_bursts_50lux_burst6810lux.csv',
#  '18887_rectangular_bursts_190lux_burst6230lux.csv',
#  '07461_rectangular_bursts_70lux_burst6090lux.csv',
#  '14601_rectangular_bursts_150lux_burst1410lux.csv',
#  '23347_rectangular_bursts_240lux_burst3280lux.csv',
#  '21390_rectangular_bursts_220lux_burst2730lux.csv',
#  '16680_rectangular_bursts_170lux_burst3180lux.csv',
#  '04537_rectangular_pulse_4547lux.csv',
#  '02321_rectangular_pulse_2331lux.csv',
#  '15917_rectangular_bursts_160lux_burst5060lux.csv',
#  '22880_rectangular_bursts_230lux_burst8120lux.csv',
#  '09768_rectangular_bursts_100lux_burst630lux.csv',
#  '03772_rectangular_pulse_3782lux.csv',
#  '19917_rectangular_bursts_200lux_burst7020lux.csv',
#  '15788_rectangular_bursts_160lux_burst3770lux.csv',
#  '10255_rectangular_bursts_100lux_burst5500lux.csv',
#  '10103_rectangular_bursts_100lux_burst3980lux.csv',
#  '09242_rectangular_bursts_90lux_burst4880lux.csv',
#  '21048_rectangular_bursts_210lux_burst8820lux.csv',
#  '21090_rectangular_bursts_210lux_burst9240lux.csv',
#  '04908_rectangular_pulse_4918lux.csv',
#  '12423_rectangular_bursts_120lux_burst8160lux.csv',
#  '01035_rectangular_pulse_1045lux.csv',
#  '18181_rectangular_bursts_180lux_burst8680lux.csv',
#  '17542_rectangular_bursts_180lux_burst2290lux.csv',
#  '03058_rectangular_pulse_3068lux.csv',
#  '07792_rectangular_bursts_70lux_burst9400lux.csv',
#  '03871_rectangular_pulse_3881lux.csv',
#  '01309_rectangular_pulse_1319lux.csv',
#  '24541_rectangular_bursts_250lux_burst5710lux.csv',
#  '11070_rectangular_bursts_110lux_burst4140lux.csv',
#  '12907_rectangular_bursts_130lux_burst3490lux.csv',
#  '05601_rectangular_bursts_50lux_burst6510lux.csv',
#  '05494_rectangular_bursts_50lux_burst5440lux.csv',
#  '03464_rectangular_pulse_3474lux.csv',
#  '14624_rectangular_bursts_150lux_burst1640lux.csv',
#  '10764_rectangular_bursts_110lux_burst1080lux.csv',
#  '21554_rectangular_bursts_220lux_burst4370lux.csv',
#  '21401_rectangular_bursts_220lux_burst2840lux.csv',
#  '18757_rectangular_bursts_190lux_burst4930lux.csv',
#  '18407_rectangular_bursts_190lux_burst1430lux.csv',
#  '23800_rectangular_bursts_240lux_burst7810lux.csv',
#  '08794_rectangular_bursts_80lux_burst9910lux.csv',
#  '05899_rectangular_bursts_50lux_burst9490lux.csv',
#  '05541_rectangular_bursts_50lux_burst5910lux.csv',
#  '02923_rectangular_pulse_2933lux.csv',
#  '24878_rectangular_bursts_250lux_burst9080lux.csv',
#  '21528_rectangular_bursts_220lux_burst4110lux.csv',
#  '14086_rectangular_bursts_140lux_burst5770lux.csv',
#  '11093_rectangular_bursts_110lux_burst4370lux.csv',
#  '14191_rectangular_bursts_140lux_burst6820lux.csv',
#  '01608_rectangular_pulse_1618lux.csv',
#  '23943_rectangular_bursts_240lux_burst9240lux.csv',
#  '07152_rectangular_bursts_70lux_burst3000lux.csv',
#  '10169_rectangular_bursts_100lux_burst4640lux.csv',
#  '00671_rectangular_pulse_681lux.csv',
#  '03165_rectangular_pulse_3175lux.csv',
#  '23786_rectangular_bursts_240lux_burst7670lux.csv',
#  '08008_rectangular_bursts_80lux_burst2050lux.csv',
#  '10270_rectangular_bursts_100lux_burst5650lux.csv',
#  '17988_rectangular_bursts_180lux_burst6750lux.csv',
#  '12940_rectangular_bursts_130lux_burst3820lux.csv',
#  '20386_rectangular_bursts_210lux_burst2200lux.csv',
#  '17344_rectangular_bursts_170lux_burst9820lux.csv',
#  '14055_rectangular_bursts_140lux_burst5460lux.csv',
#  '23271_rectangular_bursts_240lux_burst2520lux.csv',
#  '08506_rectangular_bursts_80lux_burst7030lux.csv',
#  '13910_rectangular_bursts_140lux_burst4010lux.csv',
#  '24411_rectangular_bursts_250lux_burst4410lux.csv',
#  '17258_rectangular_bursts_170lux_burst8960lux.csv',
#  '15496_rectangular_bursts_160lux_burst850lux.csv',
#  '21767_rectangular_bursts_220lux_burst6500lux.csv',
#  '12601_rectangular_bursts_120lux_burst9940lux.csv',
#  '17806_rectangular_bursts_180lux_burst4930lux.csv',
#  '17558_rectangular_bursts_180lux_burst2450lux.csv',
#  '07877_rectangular_bursts_80lux_burst740lux.csv',
#  '24682_rectangular_bursts_250lux_burst7120lux.csv',
#  '03210_rectangular_pulse_3220lux.csv',
#  '05164_rectangular_bursts_50lux_burst2140lux.csv',
#  '11966_rectangular_bursts_120lux_burst3590lux.csv',
#  '15210_rectangular_bursts_150lux_burst7500lux.csv',
#  '13520_rectangular_bursts_130lux_burst9620lux.csv',
#  '18148_rectangular_bursts_180lux_burst8350lux.csv',
#  '20319_rectangular_bursts_210lux_burst1530lux.csv',
#  '02169_rectangular_pulse_2179lux.csv',
#  '19999_rectangular_bursts_200lux_burst7840lux.csv',
#  '15368_rectangular_bursts_150lux_burst9080lux.csv',
#  '21325_rectangular_bursts_220lux_burst2080lux.csv',
#  '08146_rectangular_bursts_80lux_burst3430lux.csv',
#  '17369_rectangular_bursts_180lux_burst560lux.csv',
#  '21173_rectangular_bursts_220lux_burst560lux.csv',
#  '03711_rectangular_pulse_3721lux.csv',
#  '08448_rectangular_bursts_80lux_burst6450lux.csv',
#  '21802_rectangular_bursts_220lux_burst6850lux.csv',
#  '10919_rectangular_bursts_110lux_burst2630lux.csv',
#  '22989_rectangular_bursts_230lux_burst9210lux.csv',
#  '13281_rectangular_bursts_130lux_burst7230lux.csv',
#  '11839_rectangular_bursts_120lux_burst2320lux.csv',
#  '24663_rectangular_bursts_250lux_burst6930lux.csv',
#  '00536_rectangular_pulse_546lux.csv',
#  '08917_rectangular_bursts_90lux_burst1630lux.csv',
#  '13227_rectangular_bursts_130lux_burst6690lux.csv',
#  '19172_rectangular_bursts_190lux_burst9080lux.csv',
#  '07406_rectangular_bursts_70lux_burst5540lux.csv',
#  '06856_rectangular_bursts_60lux_burst9550lux.csv',
#  '02468_rectangular_pulse_2478lux.csv',
#  '24017_rectangular_bursts_240lux_burst9980lux.csv',
#  '10024_rectangular_bursts_100lux_burst3190lux.csv',
#  '22249_rectangular_bursts_230lux_burst1810lux.csv',
#  '12504_rectangular_bursts_120lux_burst8970lux.csv',
#  '11731_rectangular_bursts_120lux_burst1240lux.csv',
#  '00481_rectangular_pulse_491lux.csv',
#  '06125_rectangular_bursts_60lux_burst2240lux.csv',
#  '03812_rectangular_pulse_3822lux.csv',
#  '02690_rectangular_pulse_2700lux.csv',
#  '04142_rectangular_pulse_4152lux.csv',
#  '06657_rectangular_bursts_60lux_burst7560lux.csv',
#  '02054_rectangular_pulse_2064lux.csv',
#  '13887_rectangular_bursts_140lux_burst3780lux.csv',
#  '24770_rectangular_bursts_250lux_burst8000lux.csv',
#  '23536_rectangular_bursts_240lux_burst5170lux.csv',
#  '15009_rectangular_bursts_150lux_burst5490lux.csv',
#  '00748_rectangular_pulse_758lux.csv',
#  '01440_rectangular_pulse_1450lux.csv',
#  '09077_rectangular_bursts_90lux_burst3230lux.csv',
#  '12969_rectangular_bursts_130lux_burst4110lux.csv',
#  '17941_rectangular_bursts_180lux_burst6280lux.csv',
#  '09523_rectangular_bursts_90lux_burst7690lux.csv',
#  '22181_rectangular_bursts_230lux_burst1130lux.csv',
#  '12041_rectangular_bursts_120lux_burst4340lux.csv',
#  '07985_rectangular_bursts_80lux_burst1820lux.csv',
#  '20621_rectangular_bursts_210lux_burst4550lux.csv',
#  '07583_rectangular_bursts_70lux_burst7310lux.csv',
#  '17185_rectangular_bursts_170lux_burst8230lux.csv',
#  '07436_rectangular_bursts_70lux_burst5840lux.csv',
#  '13245_rectangular_bursts_130lux_burst6870lux.csv',
#  '19016_rectangular_bursts_190lux_burst7520lux.csv',
#  '14008_rectangular_bursts_140lux_burst4990lux.csv',
#  '15847_rectangular_bursts_160lux_burst4360lux.csv',
#  '21921_rectangular_bursts_220lux_burst8040lux.csv',
#  '19847_rectangular_bursts_200lux_burst6320lux.csv',
#  '02555_rectangular_pulse_2565lux.csv',
#  '24434_rectangular_bursts_250lux_burst4640lux.csv',
#  '04443_rectangular_pulse_4453lux.csv',
#  '20574_rectangular_bursts_210lux_burst4080lux.csv',
#  '11744_rectangular_bursts_120lux_burst1370lux.csv',
#  '24793_rectangular_bursts_250lux_burst8230lux.csv',
#  '12034_rectangular_bursts_120lux_burst4270lux.csv',
#  '01141_rectangular_pulse_1151lux.csv',
#  '16820_rectangular_bursts_170lux_burst4580lux.csv',
#  '05036_rectangular_bursts_50lux_burst860lux.csv',
#  '11375_rectangular_bursts_110lux_burst7190lux.csv',
#  '00718_rectangular_pulse_728lux.csv',
#  '18978_rectangular_bursts_190lux_burst7140lux.csv',
#  '15235_rectangular_bursts_150lux_burst7750lux.csv',
#  '13505_rectangular_bursts_130lux_burst9470lux.csv',
#  '11252_rectangular_bursts_110lux_burst5960lux.csv',
#  '23708_rectangular_bursts_240lux_burst6890lux.csv',
#  '10562_rectangular_bursts_100lux_burst8570lux.csv',
#  '09397_rectangular_bursts_90lux_burst6430lux.csv',
#  '18238_rectangular_bursts_180lux_burst9250lux.csv',
#  '14273_rectangular_bursts_140lux_burst7640lux.csv',
#  '14562_rectangular_bursts_150lux_burst1020lux.csv',
#  '10376_rectangular_bursts_100lux_burst6710lux.csv',
#  '23306_rectangular_bursts_240lux_burst2870lux.csv',
#  '05114_rectangular_bursts_50lux_burst1640lux.csv',
#  '05325_rectangular_bursts_50lux_burst3750lux.csv',
#  '13321_rectangular_bursts_130lux_burst7630lux.csv',
#  '15411_rectangular_bursts_150lux_burst9510lux.csv',
#  '00710_rectangular_pulse_720lux.csv',
#  '02762_rectangular_pulse_2772lux.csv',
#  '05251_rectangular_bursts_50lux_burst3010lux.csv',
#  '01849_rectangular_pulse_1859lux.csv',
#  '05060_rectangular_bursts_50lux_burst1100lux.csv',
#  '24550_rectangular_bursts_250lux_burst5800lux.csv',
#  '16575_rectangular_bursts_170lux_burst2130lux.csv',
#  '17319_rectangular_bursts_170lux_burst9570lux.csv',
#  '00657_rectangular_pulse_667lux.csv',
#  '14581_rectangular_bursts_150lux_burst1210lux.csv',
#  '07476_rectangular_bursts_70lux_burst6240lux.csv',
#  '08967_rectangular_bursts_90lux_burst2130lux.csv',
#  '12415_rectangular_bursts_120lux_burst8080lux.csv',
#  '16323_rectangular_bursts_160lux_burst9120lux.csv',
#  '10607_rectangular_bursts_100lux_burst9020lux.csv',
#  '24722_rectangular_bursts_250lux_burst7520lux.csv',
#  '12078_rectangular_bursts_120lux_burst4710lux.csv',
#  '00489_rectangular_pulse_499lux.csv',
#  '17971_rectangular_bursts_180lux_burst6580lux.csv',
#  '04199_rectangular_pulse_4209lux.csv',
#  '18187_rectangular_bursts_180lux_burst8740lux.csv',
#  '19780_rectangular_bursts_200lux_burst5650lux.csv',
#  '23138_rectangular_bursts_240lux_burst1190lux.csv',
#  '00607_rectangular_pulse_617lux.csv',
#  '06039_rectangular_bursts_60lux_burst1380lux.csv',
#  '02263_rectangular_pulse_2273lux.csv',
#  '00047_rectangular_pulse_57lux.csv',
#  '13480_rectangular_bursts_130lux_burst9220lux.csv',
#  '12898_rectangular_bursts_130lux_burst3400lux.csv',
#  '23890_rectangular_bursts_240lux_burst8710lux.csv',
#  '00740_rectangular_pulse_750lux.csv',
#  '22274_rectangular_bursts_230lux_burst2060lux.csv',
#  '07502_rectangular_bursts_70lux_burst6500lux.csv',
#  '11860_rectangular_bursts_120lux_burst2530lux.csv',
#  '10723_rectangular_bursts_110lux_burst670lux.csv',
#  '08585_rectangular_bursts_80lux_burst7820lux.csv',
#  '13426_rectangular_bursts_130lux_burst8680lux.csv',
#  '04749_rectangular_pulse_4759lux.csv',
#  '06021_rectangular_bursts_60lux_burst1200lux.csv',
#  '15888_rectangular_bursts_160lux_burst4770lux.csv',
#  '17524_rectangular_bursts_180lux_burst2110lux.csv',
#  '19888_rectangular_bursts_200lux_burst6730lux.csv',
#  '20760_rectangular_bursts_210lux_burst5940lux.csv',
#  '14176_rectangular_bursts_140lux_burst6670lux.csv',
#  '07721_rectangular_bursts_70lux_burst8690lux.csv',
#  '12342_rectangular_bursts_120lux_burst7350lux.csv',
#  '02175_rectangular_pulse_2185lux.csv',
#  '03526_rectangular_pulse_3536lux.csv',
#  '10749_rectangular_bursts_110lux_burst930lux.csv',
#  '17878_rectangular_bursts_180lux_burst5650lux.csv',
#  '16762_rectangular_bursts_170lux_burst4000lux.csv',
#  '10380_rectangular_bursts_100lux_burst6750lux.csv',
#  '23635_rectangular_bursts_240lux_burst6160lux.csv',
#  '22091_rectangular_bursts_220lux_burst9740lux.csv',
#  '15617_rectangular_bursts_160lux_burst2060lux.csv',
#  '18111_rectangular_bursts_180lux_burst7980lux.csv',
#  '13444_rectangular_bursts_130lux_burst8860lux.csv',
#  '13198_rectangular_bursts_130lux_burst6400lux.csv',
#  '13848_rectangular_bursts_140lux_burst3390lux.csv',
#  '07532_rectangular_bursts_70lux_burst6800lux.csv',
#  '04248_rectangular_pulse_4258lux.csv',
#  '24105_rectangular_bursts_250lux_burst1350lux.csv',
#  '14798_rectangular_bursts_150lux_burst3380lux.csv',
#  '09346_rectangular_bursts_90lux_burst5920lux.csv',
#  '19776_rectangular_bursts_200lux_burst5610lux.csv',
#  '07140_rectangular_bursts_70lux_burst2880lux.csv',
#  '20998_rectangular_bursts_210lux_burst8320lux.csv',
#  '05781_rectangular_bursts_50lux_burst8310lux.csv',
#  '18335_rectangular_bursts_190lux_burst710lux.csv',
#  '16961_rectangular_bursts_170lux_burst5990lux.csv',
#  '23004_rectangular_bursts_230lux_burst9360lux.csv',
#  '03027_rectangular_pulse_3037lux.csv',
#  '02474_rectangular_pulse_2484lux.csv',
#  '11618_rectangular_bursts_110lux_burst9620lux.csv',
#  '23649_rectangular_bursts_240lux_burst6300lux.csv',
#  '07565_rectangular_bursts_70lux_burst7130lux.csv',
#  '05822_rectangular_bursts_50lux_burst8720lux.csv',
#  '16336_rectangular_bursts_160lux_burst9250lux.csv',
#  '13304_rectangular_bursts_130lux_burst7460lux.csv',
#  '02861_rectangular_pulse_2871lux.csv',
#  '15434_rectangular_bursts_150lux_burst9740lux.csv',
#  '11574_rectangular_bursts_110lux_burst9180lux.csv',
#  '18927_rectangular_bursts_190lux_burst6630lux.csv',
#  '02994_rectangular_pulse_3004lux.csv',
#  '10590_rectangular_bursts_100lux_burst8850lux.csv',
#  '01586_rectangular_pulse_1596lux.csv',
#  '09427_rectangular_bursts_90lux_burst6730lux.csv',
#  '22814_rectangular_bursts_230lux_burst7460lux.csv',
#  '03478_rectangular_pulse_3488lux.csv',
#  '12824_rectangular_bursts_130lux_burst2660lux.csv',
#  '09818_rectangular_bursts_100lux_burst1130lux.csv',
#  '16037_rectangular_bursts_160lux_burst6260lux.csv',
#  '00679_rectangular_pulse_689lux.csv',
#  '16720_rectangular_bursts_170lux_burst3580lux.csv',
#  '22986_rectangular_bursts_230lux_burst9180lux.csv',
#  '08767_rectangular_bursts_80lux_burst9640lux.csv',
#  '23241_rectangular_bursts_240lux_burst2220lux.csv',
#  '12212_rectangular_bursts_120lux_burst6050lux.csv',
#  '07375_rectangular_bursts_70lux_burst5230lux.csv',
#  '09740_rectangular_bursts_90lux_burst9860lux.csv',
#  '23388_rectangular_bursts_240lux_burst3690lux.csv',
#  '09129_rectangular_bursts_90lux_burst3750lux.csv',
#  '22920_rectangular_bursts_230lux_burst8520lux.csv',
#  '24804_rectangular_bursts_250lux_burst8340lux.csv',
#  '03352_rectangular_pulse_3362lux.csv',
#  '21130_rectangular_bursts_210lux_burst9640lux.csv',
#  '20108_rectangular_bursts_200lux_burst8930lux.csv',
#  '10037_rectangular_bursts_100lux_burst3320lux.csv',
#  '15190_rectangular_bursts_150lux_burst7300lux.csv',
#  '15747_rectangular_bursts_160lux_burst3360lux.csv',
#  '11983_rectangular_bursts_120lux_burst3760lux.csv',
#  '20251_rectangular_bursts_210lux_burst850lux.csv',
#  '08227_rectangular_bursts_80lux_burst4240lux.csv',
#  '05680_rectangular_bursts_50lux_burst7300lux.csv',
#  '10833_rectangular_bursts_110lux_burst1770lux.csv',
#  '06461_rectangular_bursts_60lux_burst5600lux.csv',
#  '04084_rectangular_pulse_4094lux.csv',
#  '07906_rectangular_bursts_80lux_burst1030lux.csv',
#  '10689_rectangular_bursts_100lux_burst9840lux.csv',
#  '14854_rectangular_bursts_150lux_burst3940lux.csv',
#  '23973_rectangular_bursts_240lux_burst9540lux.csv',
#  '03179_rectangular_pulse_3189lux.csv',
#  '14019_rectangular_bursts_140lux_burst5100lux.csv',
#  '13082_rectangular_bursts_130lux_burst5240lux.csv',
#  '12730_rectangular_bursts_130lux_burst1720lux.csv',
#  '01087_rectangular_pulse_1097lux.csv',
#  '21109_rectangular_bursts_210lux_burst9430lux.csv',
#  '09748_rectangular_bursts_90lux_burst9940lux.csv',
#  '09121_rectangular_bursts_90lux_burst3670lux.csv',
#  '09663_rectangular_bursts_90lux_burst9090lux.csv',
#  '23719_rectangular_bursts_240lux_burst7000lux.csv',
#  '13729_rectangular_bursts_140lux_burst2200lux.csv',
#  '03653_rectangular_pulse_3663lux.csv',
#  '15173_rectangular_bursts_150lux_burst7130lux.csv',
#  '22224_rectangular_bursts_230lux_burst1560lux.csv',
#  '14938_rectangular_bursts_150lux_burst4780lux.csv',
#  '21564_rectangular_bursts_220lux_burst4470lux.csv',
#  '04585_rectangular_pulse_4595lux.csv',
#  '03097_rectangular_pulse_3107lux.csv',
#  '07620_rectangular_bursts_70lux_burst7680lux.csv',
#  '19458_rectangular_bursts_200lux_burst2430lux.csv',
#  '22967_rectangular_bursts_230lux_burst8990lux.csv',
#  '00061_rectangular_pulse_71lux.csv',
#  '15154_rectangular_bursts_150lux_burst6940lux.csv',
#  '08659_rectangular_bursts_80lux_burst8560lux.csv',
#  '11133_rectangular_bursts_110lux_burst4770lux.csv',
#  '01502_rectangular_pulse_1512lux.csv',
#  '12715_rectangular_bursts_130lux_burst1570lux.csv',
#  '13740_rectangular_bursts_140lux_burst2310lux.csv',
#  '22382_rectangular_bursts_230lux_burst3140lux.csv',
#  '12237_rectangular_bursts_120lux_burst6300lux.csv',
#  '05590_rectangular_bursts_50lux_burst6400lux.csv',
#  '17572_rectangular_bursts_180lux_burst2590lux.csv',
#  '07312_rectangular_bursts_70lux_burst4600lux.csv',
#  '10012_rectangular_bursts_100lux_burst3070lux.csv',
#  '08319_rectangular_bursts_80lux_burst5160lux.csv',
#  '07266_rectangular_bursts_70lux_burst4140lux.csv',
#  '04000_rectangular_pulse_4010lux.csv',
#  '23377_rectangular_bursts_240lux_burst3580lux.csv',
#  '16022_rectangular_bursts_160lux_burst6110lux.csv',
#  '02116_rectangular_pulse_2126lux.csv',
#  '03950_rectangular_pulse_3960lux.csv',
#  '12846_rectangular_bursts_130lux_burst2880lux.csv',
#  '17947_rectangular_bursts_180lux_burst6340lux.csv',
#  '17205_rectangular_bursts_170lux_burst8430lux.csv',
#  '23485_rectangular_bursts_240lux_burst4660lux.csv',
#  '00091_rectangular_pulse_101lux.csv',
#  '12545_rectangular_bursts_120lux_burst9380lux.csv',
#  '06479_rectangular_bursts_60lux_burst5780lux.csv',
#  '06704_rectangular_bursts_60lux_burst8030lux.csv',
#  '23172_rectangular_bursts_240lux_burst1530lux.csv',
#  '10554_rectangular_bursts_100lux_burst8490lux.csv',
#  '22831_rectangular_bursts_230lux_burst7630lux.csv',
#  '12801_rectangular_bursts_130lux_burst2430lux.csv',
#  '01003_rectangular_pulse_1013lux.csv',
#  '02417_rectangular_pulse_2427lux.csv',
#  '23059_rectangular_bursts_230lux_burst9910lux.csv',
#  '21661_rectangular_bursts_220lux_burst5440lux.csv',
#  '16369_rectangular_bursts_160lux_burst9580lux.csv',
#  '04501_rectangular_pulse_4511lux.csv',
#  '22363_rectangular_bursts_230lux_burst2950lux.csv',
#  '17706_rectangular_bursts_180lux_burst3930lux.csv',
#  '20264_rectangular_bursts_210lux_burst980lux.csv',
#  '09542_rectangular_bursts_90lux_burst7880lux.csv',
#  '03385_rectangular_pulse_3395lux.csv',
#  '04697_rectangular_pulse_4707lux.csv',
#  '03903_rectangular_pulse_3913lux.csv',
#  '02145_rectangular_pulse_2155lux.csv',
#  '23895_rectangular_bursts_240lux_burst8760lux.csv',
#  '04053_rectangular_pulse_4063lux.csv',
#  '19766_rectangular_bursts_200lux_burst5510lux.csv',
#  '07361_rectangular_bursts_70lux_burst5090lux.csv',
#  '24565_rectangular_bursts_250lux_burst5950lux.csv',
#  '16298_rectangular_bursts_160lux_burst8870lux.csv',
#  '16652_rectangular_bursts_170lux_burst2900lux.csv',
#  '01551_rectangular_pulse_1561lux.csv',
#  '11608_rectangular_bursts_110lux_burst9520lux.csv',
#  '05085_rectangular_bursts_50lux_burst1350lux.csv',
#  '22106_rectangular_bursts_220lux_burst9890lux.csv',
#  '16326_rectangular_bursts_160lux_burst9150lux.csv',
#  '04779_rectangular_pulse_4789lux.csv',
#  '09469_rectangular_bursts_90lux_burst7150lux.csv',
#  '20749_rectangular_bursts_210lux_burst5830lux.csv',
#  '14727_rectangular_bursts_150lux_burst2670lux.csv',
#  '07405_rectangular_bursts_70lux_burst5530lux.csv',
#  '03684_rectangular_pulse_3694lux.csv',
#  '24717_rectangular_bursts_250lux_burst7470lux.csv',
#  '17534_rectangular_bursts_180lux_burst2210lux.csv',
#  '19891_rectangular_bursts_200lux_burst6760lux.csv',
#  '21425_rectangular_bursts_220lux_burst3080lux.csv',
#  '14166_rectangular_bursts_140lux_burst6570lux.csv',
#  '09357_rectangular_bursts_90lux_burst6030lux.csv',
#  '09677_rectangular_bursts_90lux_burst9230lux.csv',
#  '00876_rectangular_pulse_886lux.csv',
#  '04552_rectangular_pulse_4562lux.csv',
#  '19324_rectangular_bursts_200lux_burst1090lux.csv',
#  '02444_rectangular_pulse_2454lux.csv',
#  '09166_rectangular_bursts_90lux_burst4120lux.csv',
#  '11631_rectangular_bursts_110lux_burst9750lux.csv',
#  '01050_rectangular_pulse_1060lux.csv',
#  '20300_rectangular_bursts_210lux_burst1340lux.csv',
#  '16798_rectangular_bursts_170lux_burst4360lux.csv',
#  '06725_rectangular_bursts_60lux_burst8240lux.csv',
#  '09461_rectangular_bursts_90lux_burst7070lux.csv',
#  '22088_rectangular_bursts_220lux_burst9710lux.csv',
#  '17868_rectangular_bursts_180lux_burst5550lux.csv',
#  '20266_rectangular_bursts_210lux_burst1000lux.csv',
#  '01694_rectangular_pulse_1704lux.csv',
#  '18504_rectangular_bursts_190lux_burst2400lux.csv',
#  '08443_rectangular_bursts_80lux_burst6400lux.csv',
#  '04278_rectangular_pulse_4288lux.csv',
#  '17124_rectangular_bursts_170lux_burst7620lux.csv',
#  '24258_rectangular_bursts_250lux_burst2880lux.csv',
#  '16696_rectangular_bursts_170lux_burst3340lux.csv',
#  '07899_rectangular_bursts_80lux_burst960lux.csv',
#  '22619_rectangular_bursts_230lux_burst5510lux.csv',
#  '10757_rectangular_bursts_110lux_burst1010lux.csv',
#  '17644_rectangular_bursts_180lux_burst3310lux.csv',
#  '00963_rectangular_pulse_973lux.csv',
#  '07927_rectangular_bursts_80lux_burst1240lux.csv',
#  '16333_rectangular_bursts_160lux_burst9220lux.csv',
#  '00218_rectangular_pulse_228lux.csv',
#  '00824_rectangular_pulse_834lux.csv',
#  '12770_rectangular_bursts_130lux_burst2120lux.csv',
#  '11664_rectangular_bursts_120lux_burst570lux.csv',
#  '03301_rectangular_pulse_3311lux.csv',
#  '14702_rectangular_bursts_150lux_burst2420lux.csv',
#  '24732_rectangular_bursts_250lux_burst7620lux.csv',
#  '01879_rectangular_pulse_1889lux.csv',
#  '08206_rectangular_bursts_80lux_burst4030lux.csv',
#  '10153_rectangular_bursts_100lux_burst4480lux.csv',
#  '03987_rectangular_pulse_3997lux.csv',
#  '21974_rectangular_bursts_220lux_burst8570lux.csv',
#  '18254_rectangular_bursts_180lux_burst9410lux.csv',
#  '10890_rectangular_bursts_110lux_burst2340lux.csv',
#  '15294_rectangular_bursts_150lux_burst8340lux.csv',
#  '19279_rectangular_bursts_200lux_burst640lux.csv',
#  '08746_rectangular_bursts_80lux_burst9430lux.csv',
#  '11870_rectangular_bursts_120lux_burst2630lux.csv',
#  '16205_rectangular_bursts_160lux_burst7940lux.csv',
#  '14263_rectangular_bursts_140lux_burst7540lux.csv',
#  '17372_rectangular_bursts_180lux_burst590lux.csv',
#  '00248_rectangular_pulse_258lux.csv',
#  '18801_rectangular_bursts_190lux_burst5370lux.csv',
#  '18638_rectangular_bursts_190lux_burst3740lux.csv',
#  '21270_rectangular_bursts_220lux_burst1530lux.csv',
#  '03600_rectangular_pulse_3610lux.csv',
#  '10292_rectangular_bursts_100lux_burst5870lux.csv',
#  '05764_rectangular_bursts_50lux_burst8140lux.csv',
#  '23630_rectangular_bursts_240lux_burst6110lux.csv',
#  '20899_rectangular_bursts_210lux_burst7330lux.csv',
#  '15612_rectangular_bursts_160lux_burst2010lux.csv',
#  '23563_rectangular_bursts_240lux_burst5440lux.csv',
#  '00181_rectangular_pulse_191lux.csv',
#  '08816_rectangular_bursts_90lux_burst620lux.csv',
#  '10873_rectangular_bursts_110lux_burst2170lux.csv',
#  '15277_rectangular_bursts_150lux_burst8170lux.csv',
#  '07435_rectangular_bursts_70lux_burst5830lux.csv',
#  '05859_rectangular_bursts_50lux_burst9090lux.csv',
#  '22915_rectangular_bursts_230lux_burst8470lux.csv',
#  '05520_rectangular_bursts_50lux_burst5700lux.csv',
#  '01218_rectangular_pulse_1228lux.csv',
#  '05711_rectangular_bursts_50lux_burst7610lux.csv',
#  '20588_rectangular_bursts_210lux_burst4220lux.csv',
#  '22703_rectangular_bursts_230lux_burst6350lux.csv',
#  '08608_rectangular_bursts_80lux_burst8050lux.csv',
#  '08831_rectangular_bursts_90lux_burst770lux.csv',
#  '22256_rectangular_bursts_230lux_burst1880lux.csv',
#  '17404_rectangular_bursts_180lux_burst910lux.csv',
#  '22821_rectangular_bursts_230lux_burst7530lux.csv',
#  '15461_rectangular_bursts_160lux_burst500lux.csv',
#  '12976_rectangular_bursts_130lux_burst4180lux.csv',
#  '16379_rectangular_bursts_160lux_burst9680lux.csv',
#  '11001_rectangular_bursts_110lux_burst3450lux.csv',
#  '11351_rectangular_bursts_110lux_burst6950lux.csv',
#  '11389_rectangular_bursts_110lux_burst7330lux.csv',
#  '13959_rectangular_bursts_140lux_burst4500lux.csv',
#  '16836_rectangular_bursts_170lux_burst4740lux.csv',
#  '07752_rectangular_bursts_70lux_burst9000lux.csv',
#  '18673_rectangular_bursts_190lux_burst4090lux.csv',
#  '10239_rectangular_bursts_100lux_burst5340lux.csv',
#  '05665_rectangular_bursts_50lux_burst7150lux.csv',
#  '08348_rectangular_bursts_80lux_burst5450lux.csv',
#  '01927_rectangular_pulse_1937lux.csv',
#  '00808_rectangular_pulse_818lux.csv',
#  '05454_rectangular_bursts_50lux_burst5040lux.csv',
#  '04924_rectangular_pulse_4934lux.csv',
#  '21490_rectangular_bursts_220lux_burst3730lux.csv',
#  '12399_rectangular_bursts_120lux_burst7920lux.csv',
#  '14943_rectangular_bursts_150lux_burst4830lux.csv',
#  '01719_rectangular_pulse_1729lux.csv',
#  '10000_rectangular_bursts_100lux_burst2950lux.csv',
#  '15742_rectangular_bursts_160lux_burst3310lux.csv',
#  '08194_rectangular_bursts_80lux_burst3910lux.csv',
#  '22392_rectangular_bursts_230lux_burst3240lux.csv',
#  '00858_rectangular_pulse_868lux.csv',
#  '00264_rectangular_pulse_274lux.csv',
#  '16032_rectangular_bursts_160lux_burst6210lux.csv',
#  '17038_rectangular_bursts_170lux_burst6760lux.csv',
#  '23244_rectangular_bursts_240lux_burst2250lux.csv',
#  '22211_rectangular_bursts_230lux_burst1430lux.csv',
#  '22866_rectangular_bursts_230lux_burst7980lux.csv',
#  '07192_rectangular_bursts_70lux_burst3400lux.csv',
#  '00323_rectangular_pulse_333lux.csv',
#  '19400_rectangular_bursts_200lux_burst1850lux.csv',
#  '06685_rectangular_bursts_60lux_burst7840lux.csv',
#  '10105_rectangular_bursts_100lux_burst4000lux.csv',
#  '21826_rectangular_bursts_220lux_burst7090lux.csv',
#  '19492_rectangular_bursts_200lux_burst2770lux.csv',
#  '21687_rectangular_bursts_220lux_burst5700lux.csv',
#  '24045_rectangular_bursts_250lux_burst750lux.csv',
#  '09560_rectangular_bursts_90lux_burst8060lux.csv',
#  '02031_rectangular_pulse_2041lux.csv',
#  '04627_rectangular_pulse_4637lux.csv',
#  '01325_rectangular_pulse_1335lux.csv',
#  '14964_rectangular_bursts_150lux_burst5040lux.csv',
#  '23480_rectangular_bursts_240lux_burst4610lux.csv',
#  '07283_rectangular_bursts_70lux_burst4310lux.csv',
#  '02688_rectangular_pulse_2698lux.csv',
#  '22234_rectangular_bursts_230lux_burst1660lux.csv',
#  '03448_rectangular_pulse_3458lux.csv',
#  '20503_rectangular_bursts_210lux_burst3370lux.csv',
#  '19844_rectangular_bursts_200lux_burst6290lux.csv',
#  '00371_rectangular_pulse_381lux.csv',
#  '11949_rectangular_bursts_120lux_burst3420lux.csv',
#  '08003_rectangular_bursts_80lux_burst2000lux.csv',
#  '24647_rectangular_bursts_250lux_burst6770lux.csv',
#  '22996_rectangular_bursts_230lux_burst9280lux.csv',
#  '16027_rectangular_bursts_160lux_burst6160lux.csv',
#  '16730_rectangular_bursts_170lux_burst3680lux.csv',
#  '09568_rectangular_bursts_90lux_burst8140lux.csv',
#  '02530_rectangular_pulse_2540lux.csv',
#  '04326_rectangular_pulse_4336lux.csv',
#  '09223_rectangular_bursts_90lux_burst4690lux.csv',
#  '22930_rectangular_bursts_230lux_burst8620lux.csv',
#  '23617_rectangular_bursts_240lux_burst5980lux.csv',
#  '09279_rectangular_bursts_90lux_burst5250lux.csv',
#  '14987_rectangular_bursts_150lux_burst5270lux.csv',
#  '02389_rectangular_pulse_2399lux.csv',
#  '20486_rectangular_bursts_210lux_burst3200lux.csv',
#  '04819_rectangular_pulse_4829lux.csv',
#  '21120_rectangular_bursts_210lux_burst9540lux.csv',
#  '01624_rectangular_pulse_1634lux.csv',
#  '20111_rectangular_bursts_200lux_burst8960lux.csv',
#  '16535_rectangular_bursts_170lux_burst1730lux.csv',
#  '13745_rectangular_bursts_140lux_burst2360lux.csv',
#  '01992_rectangular_pulse_2002lux.csv',
#  '06382_rectangular_bursts_60lux_burst4810lux.csv',
#  '03149_rectangular_pulse_3159lux.csv',
#  '16813_rectangular_bursts_170lux_burst4510lux.csv',
#  '07661_rectangular_bursts_70lux_burst8090lux.csv',
#  '17294_rectangular_bursts_170lux_burst9320lux.csv',
#  '03227_rectangular_pulse_3237lux.csv',
#  '12836_rectangular_bursts_130lux_burst2780lux.csv',
#  '05022_rectangular_bursts_50lux_burst720lux.csv',
#  '02674_rectangular_pulse_2684lux.csv',
#  '12507_rectangular_bursts_120lux_burst9000lux.csv',
#  '20412_rectangular_bursts_210lux_burst2460lux.csv',
#  '18664_rectangular_bursts_190lux_burst4000lux.csv',
#  '13372_rectangular_bursts_130lux_burst8140lux.csv',
#  '10332_rectangular_bursts_100lux_burst6270lux.csv',
#  '21851_rectangular_bursts_220lux_burst7340lux.csv',
#  '12890_rectangular_bursts_130lux_burst3320lux.csv',
#  '18370_rectangular_bursts_190lux_burst1060lux.csv',
#  '15474_rectangular_bursts_160lux_burst630lux.csv',
#  '14333_rectangular_bursts_140lux_burst8240lux.csv',
#  '15676_rectangular_bursts_160lux_burst2650lux.csv',
#  '17819_rectangular_bursts_180lux_burst5060lux.csv',
#  '04048_rectangular_pulse_4058lux.csv',
#  '15124_rectangular_bursts_150lux_burst6640lux.csv',
#  '03918_rectangular_pulse_3928lux.csv',
#  '06285_rectangular_bursts_60lux_burst3840lux.csv',
#  '11143_rectangular_bursts_110lux_burst4870lux.csv',
#  '13996_rectangular_bursts_140lux_burst4870lux.csv',
#  '11814_rectangular_bursts_120lux_burst2070lux.csv',
#  '00431_rectangular_pulse_441lux.csv',
#  '02375_rectangular_pulse_2385lux.csv',
#  '20341_rectangular_bursts_210lux_burst1750lux.csv',
#  '19717_rectangular_bursts_200lux_burst5020lux.csv',
#  '03726_rectangular_pulse_3736lux.csv',
#  '20779_rectangular_bursts_210lux_burst6130lux.csv',
#  '14801_rectangular_bursts_150lux_burst3410lux.csv',
#  '23029_rectangular_bursts_230lux_burst9610lux.csv',
#  '18687_rectangular_bursts_190lux_burst4230lux.csv',
#  '16425_rectangular_bursts_170lux_burst630lux.csv',
#  '05816_rectangular_bursts_50lux_burst8660lux.csv',
#  '04549_rectangular_pulse_4559lux.csv',
#  '21509_rectangular_bursts_220lux_burst3920lux.csv',
#  '16357_rectangular_bursts_160lux_burst9460lux.csv',
#  '23468_rectangular_bursts_240lux_burst4490lux.csv',
#  '06765_rectangular_bursts_60lux_burst8640lux.csv',
#  '08403_rectangular_bursts_80lux_burst6000lux.csv',
#  '21576_rectangular_bursts_220lux_burst4590lux.csv',
#  '14346_rectangular_bursts_140lux_burst8370lux.csv',
#  '15663_rectangular_bursts_160lux_burst2520lux.csv',
#  '05054_rectangular_bursts_50lux_burst1040lux.csv',
#  '10843_rectangular_bursts_110lux_burst1870lux.csv',
#  '17494_rectangular_bursts_180lux_burst1810lux.csv',
#  '11298_rectangular_bursts_110lux_burst6420lux.csv',
#  '13013_rectangular_bursts_130lux_burst4550lux.csv',
#  '10964_rectangular_bursts_110lux_burst3080lux.csv',
#  '14824_rectangular_bursts_150lux_burst3640lux.csv',
#  '05265_rectangular_bursts_50lux_burst3150lux.csv',
#  '02063_rectangular_pulse_2073lux.csv',
#  '03825_rectangular_pulse_3835lux.csv',
#  '24920_rectangular_bursts_250lux_burst9500lux.csv',
#  '00708_rectangular_pulse_718lux.csv',
#  '17560_rectangular_bursts_180lux_burst2470lux.csv',
#  '07967_rectangular_bursts_80lux_burst1640lux.csv',
#  '10317_rectangular_bursts_100lux_burst6120lux.csv',
#  '08246_rectangular_bursts_80lux_burst4430lux.csv',
#  '15991_rectangular_bursts_160lux_burst5800lux.csv',
#  '12707_rectangular_bursts_130lux_burst1490lux.csv',
#  '19612_rectangular_bursts_200lux_burst3970lux.csv',
#  '23365_rectangular_bursts_240lux_burst3460lux.csv',
#  '00586_rectangular_pulse_596lux.csv',
#  '13190_rectangular_bursts_130lux_burst6320lux.csv',
#  '11466_rectangular_bursts_110lux_burst8100lux.csv',
#  '13518_rectangular_bursts_130lux_burst9600lux.csv',
#  '12854_rectangular_bursts_130lux_burst2960lux.csv',
#  '23600_rectangular_bursts_240lux_burst5810lux.csv',
#  '05311_rectangular_bursts_50lux_burst3610lux.csv',
#  '18957_rectangular_bursts_190lux_burst6930lux.csv',
#  '17076_rectangular_bursts_170lux_burst7140lux.csv',
#  '05120_rectangular_bursts_50lux_burst1700lux.csv',
#  '23692_rectangular_bursts_240lux_burst6730lux.csv',
#  '08706_rectangular_bursts_80lux_burst9030lux.csv',
#  '00758_rectangular_pulse_768lux.csv',
#  '07592_rectangular_bursts_70lux_burst7400lux.csv',
#  '02562_rectangular_pulse_2572lux.csv',
#  '12019_rectangular_bursts_120lux_burst4120lux.csv',
#  '10666_rectangular_bursts_100lux_burst9610lux.csv',
#  '23497_rectangular_bursts_240lux_burst4780lux.csv',
#  '02977_rectangular_pulse_2987lux.csv',
#  '14948_rectangular_bursts_150lux_burst4880lux.csv',
#  '16447_rectangular_bursts_170lux_burst850lux.csv',
#  '16878_rectangular_bursts_170lux_burst5160lux.csv',
#  '18840_rectangular_bursts_190lux_burst5760lux.csv',
#  '15101_rectangular_bursts_150lux_burst6410lux.csv',
#  '18003_rectangular_bursts_180lux_burst6900lux.csv',
#  '02899_rectangular_pulse_2909lux.csv',
#  '08594_rectangular_bursts_80lux_burst7910lux.csv',
#  '21184_rectangular_bursts_220lux_burst670lux.csv',
#  '18225_rectangular_bursts_180lux_burst9120lux.csv',
#  '12740_rectangular_bursts_130lux_burst1820lux.csv',
#  '17788_rectangular_bursts_180lux_burst4750lux.csv',
#  '09386_rectangular_bursts_90lux_burst6320lux.csv',
#  '02617_rectangular_pulse_2627lux.csv',
#  '03895_rectangular_pulse_3905lux.csv',
#  '20565_rectangular_bursts_210lux_burst3990lux.csv',
#  '04701_rectangular_pulse_4711lux.csv',
#  '24739_rectangular_bursts_250lux_burst7690lux.csv',
#  '14709_rectangular_bursts_150lux_burst2490lux.csv',
#  '07252_rectangular_bursts_70lux_burst4000lux.csv',
#  '07830_rectangular_bursts_70lux_burst9780lux.csv',
#  '22594_rectangular_bursts_230lux_burst5260lux.csv',
#  '08901_rectangular_bursts_90lux_burst1470lux.csv',
#  '08648_rectangular_bursts_80lux_burst8450lux.csv',
#  '24253_rectangular_bursts_250lux_burst2830lux.csv',
#  '19799_rectangular_bursts_200lux_burst5840lux.csv',
#  '22742_rectangular_bursts_230lux_burst6740lux.csv',
#  '00663_rectangular_pulse_673lux.csv',
#  '15629_rectangular_bursts_160lux_burst2180lux.csv',
#  '08308_rectangular_bursts_80lux_burst5050lux.csv',
#  '00724_rectangular_pulse_734lux.csv',
#  '07326_rectangular_bursts_70lux_burst4740lux.csv',
#  '01885_rectangular_pulse_1895lux.csv',
#  '00031_rectangular_pulse_41lux.csv',
#  '11766_rectangular_bursts_120lux_burst1590lux.csv',
#  '21997_rectangular_bursts_220lux_burst8800lux.csv',
#  '01203_rectangular_pulse_1213lux.csv',
#  '18513_rectangular_bursts_190lux_burst2490lux.csv',
#  '04200_rectangular_pulse_4210lux.csv',
#  '02316_rectangular_pulse_2326lux.csv',
#  '15444_rectangular_bursts_150lux_burst9840lux.csv',
#  '04886_rectangular_pulse_4896lux.csv',
#  '07035_rectangular_bursts_70lux_burst1830lux.csv',
#  '21602_rectangular_bursts_220lux_burst4850lux.csv',
#  '08909_rectangular_bursts_90lux_burst1550lux.csv',
#  '10158_rectangular_bursts_100lux_burst4530lux.csv',
#  '15592_rectangular_bursts_160lux_burst1810lux.csv',
#  '13434_rectangular_bursts_130lux_burst8760lux.csv',
#  '21357_rectangular_bursts_220lux_burst2400lux.csv',
#  '01702_rectangular_pulse_1712lux.csv',
#  '02829_rectangular_pulse_2839lux.csv',
#  '07783_rectangular_bursts_70lux_burst9310lux.csv',
#  '09069_rectangular_bursts_90lux_burst3150lux.csv',
#  '03453_rectangular_pulse_3463lux.csv',
#  '12273_rectangular_bursts_120lux_burst6660lux.csv',
#  '18590_rectangular_bursts_190lux_burst3260lux.csv',
#  '13687_rectangular_bursts_140lux_burst1780lux.csv',
#  '11931_rectangular_bursts_120lux_burst3240lux.csv',
#  '16056_rectangular_bursts_160lux_burst6450lux.csv',
#  '05485_rectangular_bursts_50lux_burst5350lux.csv',
#  '04785_rectangular_pulse_4795lux.csv',
#  '13351_rectangular_bursts_130lux_burst7930lux.csv',
#  '03297_rectangular_pulse_3307lux.csv',
#  '20542_rectangular_bursts_210lux_burst3760lux.csv',
#  '11671_rectangular_bursts_120lux_burst640lux.csv',
#  '17741_rectangular_bursts_180lux_burst4280lux.csv',
#  '13411_rectangular_bursts_130lux_burst8530lux.csv',
#  '01801_rectangular_pulse_1811lux.csv',
#  '20821_rectangular_bursts_210lux_burst6550lux.csv',
#  '03379_rectangular_pulse_3389lux.csv',
#  '16085_rectangular_bursts_160lux_burst6740lux.csv',
#  '01287_rectangular_pulse_1297lux.csv',
#  '05888_rectangular_bursts_50lux_burst9380lux.csv',
#  '10056_rectangular_bursts_100lux_burst3510lux.csv',
#  '23627_rectangular_bursts_240lux_burst6080lux.csv',
#  '07344_rectangular_bursts_70lux_burst4920lux.csv',
#  '22550_rectangular_bursts_230lux_burst4820lux.csv',
#  '09142_rectangular_bursts_90lux_burst3880lux.csv',
#  '24297_rectangular_bursts_250lux_burst3270lux.csv',
#  '08043_rectangular_bursts_80lux_burst2400lux.csv',
#  '19647_rectangular_bursts_200lux_burst4320lux.csv',
#  '03152_rectangular_pulse_3162lux.csv',
#  '23422_rectangular_bursts_240lux_burst4030lux.csv',
#  '11944_rectangular_bursts_120lux_burst3370lux.csv',
#  '13456_rectangular_bursts_130lux_burst8980lux.csv',
#  '09061_rectangular_bursts_90lux_burst3070lux.csv',
#  '14555_rectangular_bursts_150lux_burst950lux.csv',
#  '04284_rectangular_pulse_4294lux.csv',
#  '16467_rectangular_bursts_170lux_burst1050lux.csv',
#  '22517_rectangular_bursts_230lux_burst4490lux.csv',
#  '02914_rectangular_pulse_2924lux.csv',
#  '04802_rectangular_pulse_4812lux.csv',
#  '21452_rectangular_bursts_220lux_burst3350lux.csv',
#  '18778_rectangular_bursts_190lux_burst5140lux.csv',
#  '12000_rectangular_bursts_120lux_burst3930lux.csv',
#  '01786_rectangular_pulse_1796lux.csv',
#  '00016_rectangular_pulse_26lux.csv',
#  '03678_rectangular_pulse_3688lux.csv',
#  '24606_rectangular_bursts_250lux_burst6360lux.csv',
#  '08939_rectangular_bursts_90lux_burst1850lux.csv',
#  '19430_rectangular_bursts_200lux_burst2150lux.csv',
#  '10399_rectangular_bursts_100lux_burst6940lux.csv',
#  '13316_rectangular_bursts_130lux_burst7580lux.csv',
#  '00776_rectangular_pulse_786lux.csv',
#  '09723_rectangular_bursts_90lux_burst9690lux.csv',
#  '07005_rectangular_bursts_70lux_burst1530lux.csv',
#  '24274_rectangular_bursts_250lux_burst3040lux.csv',
#  '10414_rectangular_bursts_100lux_burst7090lux.csv',
#  '16130_rectangular_bursts_160lux_burst7190lux.csv',
#  '12380_rectangular_bursts_120lux_burst7730lux.csv',
#  '12609_rectangular_bursts_130lux_burst510lux.csv',
#  '19722_rectangular_bursts_200lux_burst5070lux.csv',
#  '11146_rectangular_bursts_110lux_burst4900lux.csv',
#  '15960_rectangular_bursts_160lux_burst5490lux.csv',
#  '19206_rectangular_bursts_190lux_burst9420lux.csv',
#  '16352_rectangular_bursts_160lux_burst9410lux.csv',
#  '02595_rectangular_pulse_2605lux.csv',
#  '01852_rectangular_pulse_1862lux.csv',
#  '13273_rectangular_bursts_130lux_burst7150lux.csv',
#  '23832_rectangular_bursts_240lux_burst8130lux.csv',
#  '07809_rectangular_bursts_70lux_burst9570lux.csv',
#  '05190_rectangular_bursts_50lux_burst2400lux.csv',
#  '20417_rectangular_bursts_210lux_burst2510lux.csv',
#  '14916_rectangular_bursts_150lux_burst4560lux.csv',
#  '12838_rectangular_bursts_130lux_burst2800lux.csv',
#  '00200_rectangular_pulse_210lux.csv',
#  '12964_rectangular_bursts_130lux_burst4060lux.csv',
#  '18375_rectangular_bursts_190lux_burst1110lux.csv',
#  '18235_rectangular_bursts_180lux_burst9220lux.csv',
#  '16381_rectangular_bursts_160lux_burst9700lux.csv',
#  '03400_rectangular_pulse_3410lux.csv',
#  '16882_rectangular_bursts_170lux_burst5200lux.csv',
#  '22472_rectangular_bursts_230lux_burst4040lux.csv',
#  '00347_rectangular_pulse_357lux.csv',
#  '19674_rectangular_bursts_200lux_burst4590lux.csv',
#  '15673_rectangular_bursts_160lux_burst2620lux.csv',
#  '16019_rectangular_bursts_160lux_burst6080lux.csv',
#  '18489_rectangular_bursts_190lux_burst2250lux.csv',
#  '08897_rectangular_bursts_90lux_burst1430lux.csv',
#  '12156_rectangular_bursts_120lux_burst5490lux.csv',
#  '13248_rectangular_bursts_130lux_burst6900lux.csv',
#  '24930_rectangular_bursts_250lux_burst9600lux.csv',
#  '19519_rectangular_bursts_200lux_burst3040lux.csv',
#  '16545_rectangular_bursts_170lux_burst1830lux.csv',
#  '04851_rectangular_pulse_4861lux.csv',
#  '02947_rectangular_pulse_2957lux.csv',
#  '06079_rectangular_bursts_60lux_burst1780lux.csv',
#  '00317_rectangular_pulse_327lux.csv',
#  '11476_rectangular_bursts_110lux_burst8200lux.csv',
#  '14112_rectangular_bursts_140lux_burst6030lux.csv',
#  '18396_rectangular_bursts_190lux_burst1320lux.csv',
#  '13508_rectangular_bursts_130lux_burst9500lux.csv',
#  '00250_rectangular_pulse_260lux.csv',
#  '12185_rectangular_bursts_120lux_burst5780lux.csv',
#  '05750_rectangular_bursts_50lux_burst8000lux.csv',
#  '13584_rectangular_bursts_140lux_burst750lux.csv',
#  '17683_rectangular_bursts_180lux_burst3700lux.csv',
#  '03101_rectangular_pulse_3111lux.csv',
#  '11658_rectangular_bursts_120lux_burst510lux.csv',
#  ...]

# %%
# Process each file
for file in tqdm(csv_files[0:10]):
    # Extract scenario name from filename (without extension)
    scenario_name = os.path.splitext(file)[0]
    
    # Load the scenario data
    scenario = pd.read_csv(folder + file, sep=",", decimal=".",
                          header=0, names=['hours', 'irradiance_mel'])
        
    # input_irradiance = irradiance + scenario['irradiance_mel'].tolist()
    input_irradiance = irradiance + daytime_pattern(time_points) 

    interpolator = interp1d(
        np.linspace(0, 3 * 24 * 60 * 60, len(input_irradiance), dtype=int), # seconds in 3 days
        input_irradiance, # 3 days of data at 1 minute intervals
        kind="cubic",
        bounds_error=False,
        fill_value=(input_irradiance[0], input_irradiance[-1]),
    )

    # Run the model
    sol, t = models.model_run(3, 1000, interpolator=interpolator, waketime = 8, bedtime = 20, debug=False)
    
    # Store the solution with the scenario name as key
    scenario_results[scenario_name] = {
        'solution': sol,
        'time': t,
        'irradiance': input_irradiance,
        'scenario_data': scenario,
    }

with open(output_filename, 'wb') as f:
    pickle.dump(scenario_results, f)
    
print(f"Processed {len(scenario_results)} scenarios")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Processed 10 scenarios

# %%
# Load previously saved results
# import pickle

# output_filename = './scenario_results_20250623-195622.pkl'

# # Load the results
# with open(output_filename, 'rb') as f:
#     scenario_results = pickle.load(f)

# %%
# go through the loaded results and calculate KSS, AMT6, and RHO_B
# find scnarios in each category that have the same KSS, AMT6, and RHO_B
# TODO: the alertness should be the same during the 13-15h window on the third day
from tqdm.notebook import tqdm

metrics = {}
for scenario_name, data in tqdm(scenario_results.items()):
    sol = data['solution']
    t = data['time']
    irradiance = data['irradiance']
    scenario_data = data['scenario_data']

    interpolator = interp1d(
        np.linspace(0, 3 * 24 * 60 * 60, 4320, dtype=int),
        irradiance,
        kind="cubic",
        bounds_error=False,
        fill_value=(irradiance[0], irradiance[-1]),
    )
    
    # Calculate KSS, AMT6, and RHO_B
    V_v = sol[:, 0]
    V_m = sol[:, 1]
    H = sol[:, 2]
    X = sol[:, 3]
    Y = sol[:, 4]
    P = sol[:, 5]
    Theta_L = sol[:, 6]
    A = sol[:,7]
    rho_b = sol[:, 8]
    C = models.circadian_drive_v(X,Y)
    KSS = models.alertness_measure_v(C, H, Theta_L)
    IE = [models.irradiance(time, interpolator) for time in t]
    aMT6s = [models.urinary_excretion_rate(rho_b, t, time) for time in t]
    
    metrics[scenario_name] = {
        'V_v': V_v,
        'V_m': V_m,
        'H': H,
        'X': X,
        'Y': Y,
        'P': P,
        'Theta_L': Theta_L,
        'A': A,
        'KSS': KSS,
        'aMT6s': aMT6s,
        'RHO_B': rho_b,
        'irradiance': irradiance,
        'IE': IE,
        'time': t,
        'scenario_data': scenario_data
    }
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
rectangular_pulse_scenarios = {k: v for k, v in metrics.items() if 'rectangular_pulse' in k}  
rectangular_bursts_scenarios = {k: v for k, v in metrics.items() if 'rectangular_bursts' in k}

# temp = rectangular_bursts_scenarios['21531_rectangular_bursts_220lux_burst4140lux']
temp = rectangular_pulse_scenarios['02007_rectangular_pulse_2017lux']

Sigmoid = [models.sigmoid(irr) for irr in temp['IE']]
# Sigmoid = [(models.sigmoid(irr) - models.sigmoid(0)) / (models.sigmoid(1000) - models.sigmoid(0)) for irr in temp['IE']]
# Sigmoid = ( models.sigmoid_v(temp['IE']) - models.sigmoid_v(0) ) / ( models.sigmoid_v(1000) - models.sigmoid_v(0) )

fig, axs = plt.subplots(4, 1, figsize=(14, 10))

# axs[0].plot(temp['time'], temp['irradiance'])
# axs[0].set_title(f"Irradiance")

axs[0].plot(temp['time'], temp['IE'])
axs[0].set_title(f"Irradiance")

axs[1].plot(temp['time'], temp['KSS'])
axs[1].set_title(f"KSS")

axs[2].plot(temp['time'], Sigmoid)
axs[2].set_title(f"Sigmoid")

axs[3].plot(temp['time'], temp['Theta_L'])
axs[3].set_title(f"Theta_L")
# Out:
# Text(0.5, 1.0, 'Theta_L')

# %%
V_v = temp['V_v']
V_m = temp['V_m']
H = temp['H']
X = temp['X']
Y = temp['Y']
P = temp['P']
Theta_L = temp['Theta_L']
A = temp['A']
rho_b = temp['RHO_B']
aMT6s = temp['aMT6s']
t_hours = temp['time']/3600

### Plot ODEs
plt.figure(figsize=(10, 10))

plt.subplot(4,2,1)
plt.plot(t_hours, V_v, 'b', label='V_v(t)')
plt.plot(t_hours, V_m, 'g', label='V_m(t)')
plt.legend(loc='best')
plt.xlabel('t')
plt.grid(True)

plt.subplot(4,2,2)
plt.plot(t_hours, X, 'c', label='X(t)')
plt.plot(t_hours, Y, 'm', label='Y(t)')
plt.legend(loc='best')
plt.xlabel('t')
plt.grid(True)

plt.subplot(4,2,3)
plt.plot(t_hours, H, 'r', label='H(t)')
plt.legend(loc='best')
plt.xlabel('t')
plt.grid(True)

plt.subplot(4,2,4)
plt.plot(t_hours, P, 'r', label='P(t)')
plt.legend(loc='best')
plt.xlabel('t')
plt.grid(True)

plt.subplot(4,2,5)
plt.plot(t_hours, Theta_L, 'b', label='Theta_L(t)')
plt.legend(loc='best')
plt.xlabel('t')
plt.grid(True)

plt.subplot(4,2,6)
plt.plot(t_hours, A, 'b', label='A(t)')
plt.legend(loc='best')
plt.xlabel('t')
plt.grid(True)

plt.subplot(4,2,7)
plt.plot(t_hours, rho_b, 'b', label='rho_b(t)')
plt.legend(loc='best')
plt.xlabel('t')
plt.grid(True)

plt.subplot(4,2,8)
# Primary axis for rho_b
ax1 = plt.gca()
ax1.plot(t_hours, rho_b, label='rho_b(t)', color='darkorange')
ax1.set_xlabel('Time (hours)')
ax1.set_ylabel('Blood Concentration', color='darkorange')
ax1.tick_params(axis='y', labelcolor='darkorange')
ax1.grid(True)

# Secondary axis for aMT6s
ax2 = ax1.twinx()
ax2.plot(t_hours, aMT6s, label='u(t)', color='blue')
ax2.set_ylabel('Urinary Excretion Rate', color='blue')
ax2.tick_params(axis='y', labelcolor='blue')

# Create combined legend
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

plt.tight_layout()
plt.show()

# %%
for scenario_name, data in tqdm(rectangular_pulse_scenarios.items()):
    KSS = data['KSS']
    AMT6 = data['aMT6s']
    RHO_B = data['RHO_B']
    
    # Find the first scenario in each category that has the same KSS

    for name, metrics_data in rectangular_bursts_scenarios.items():
        if np.isclose(KSS, metrics_data['KSS'], atol=0.05).all():
            print(f"Found matching scenario: {name} for {scenario_name}")
            break
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Found matching scenario: 21531_rectangular_bursts_220lux_burst4140lux for 03192_rectangular_pulse_3202lux
# Found matching scenario: 21531_rectangular_bursts_220lux_burst4140lux for 01413_rectangular_pulse_1423lux
# Found matching scenario: 21531_rectangular_bursts_220lux_burst4140lux for 02007_rectangular_pulse_2017lux

# %%
# Find one scenario in each category (constant, morning peak, afternoon peak, daylight) that has the same KSS, AMT6, and RHO_B (or close enough)
# Pick the first scenario in category constant, then loop over the other categories and find the first scenario that has the same KSS, AMT6, and RHO_B

# filter metrics' scenario name that include the word constant
# constant_scenarios = {k: v for k, v in metrics.items() if 'constant' in k}
# morning_peak_scenarios = {k: v for k, v in metrics.items() if 'morning_peak' in k}
# afternoon_peak_scenarios = {k: v for k, v in metrics.items() if 'afternoon_peak' in k}
# daylight_scenarios = {k: v for k, v in metrics.items() if 'daylight' in k}

# len(constant_scenarios), len(morning_peak_scenarios), len(afternoon_peak_scenarios), len(daylight_scenarios)

# first_key = next(iter(constant_scenarios))
# first_value = constant_scenarios[first_key]
# print(f"First scenario: {first_key}")
# print(f"KSS : {first_value['KSS']}")
# print(f"AMT6: {first_value['AMT6']}")
# print(f"RHO_B: {first_value['RHO_B']}")

# %%
# for scenario_name, data in tqdm(constant_scenarios.items()):
#     KSS = data['KSS']
#     AMT6 = data['aMT6s']
#     RHO_B = data['RHO_B']
    
#     # Find the first scenario in each category that has the same KSS, AMT6, and RHO_B
#     for category, scenarios in [('morning_peak', morning_peak_scenarios), 
#                                 ('afternoon_peak', afternoon_peak_scenarios), 
#                                 ('daylight', daylight_scenarios)]:
#         for name, metrics_data in scenarios.items():
#             if np.isclose(KSS, metrics_data['KSS'], atol=0.005).all():
#                 print(f"Found matching scenario: {name} in category {category} for {scenario_name}")
#                 break

# %%
# Define the scenario names for easier reference
labels = {
    'constant': '00092_constant_930lux',
    'morning_peak': '01704_morning_peak_830lux_peak7p0x',
    'afternoon_peak': '06879_afternoon_peak_880lux_peak2p0x',
    'daylight': '10692_daylight_1930lux'
} # tol = 0.01

labels = {
    'constant': '00267_constant_2680lux',
    'morning_peak': '04336_morning_peak_2380lux_peak5p5x',
    'afternoon_peak': '09620_afternoon_peak_2490lux_peak4p0x',
    'daylight': '11193_daylight_6940lux'
} # tol = 0.005

labels = {
    'rectangular_pulse': '00578_rectangular_pulse_588lux',
    'rectangular_bursts': '19295_rectangular_bursts_200lux_burst800lux'
}

# Get the common time vector
t = metrics['00578_rectangular_pulse_588lux']['time']
t_hours = t / 3600  # Convert seconds to hours

# Create a figure with three subplots
plt.figure(figsize=(15, 12))

# Plot 1: KSS for all scenarios
plt.subplot(4, 1, 1)
for label, scenario in labels.items():
    plt.plot(t_hours, metrics[scenario]['KSS'], label=scenario)
plt.title('Karolinska Sleepiness Scale (KSS)')
plt.ylabel('KSS Value')
plt.legend()
plt.grid(True)
plt.xlim(48, 72)
plt.xticks(range(48, 72, 1), range(0, 24, 1))

# Plot 2: AMT6 for all scenarios
plt.subplot(4, 1, 2)
for label, scenario in labels.items():
    plt.plot(t_hours, metrics[scenario]['aMT6s'], label=scenario)
plt.title('Urinary 6-sulphatoxymelatonin (aMT6s)')
plt.ylabel('aMT6saMT6s Value')
plt.legend()
plt.grid(True)
plt.xlim(48, 72)
plt.xticks(range(48, 72, 1), range(0, 24, 1))

# Plot 3: RHO_B for all scenarios
plt.subplot(4, 1, 3)
for label, scenario in labels.items():
    plt.plot(t_hours, metrics[scenario]['RHO_B'], label=scenario)
plt.title('Melatonin in Blood Plasma (RHO_B)')
plt.xlabel('Time (hours)')
plt.ylabel('RHO_B Value')
plt.legend()
plt.grid(True)
plt.xlim(48, 72)
plt.xticks(range(48, 72, 1), range(0, 24, 1))

# Plot 4: Irradiance for all scenarios
plt.subplot(4, 1, 4)  # Added new subplot for irradiance
for label, scenario in labels.items():
    plt.plot(t_hours, metrics[scenario]['irradiance'], label=scenario)
plt.title('Melanopic Equivalent Daylight Illuminance (Irradiance)')
plt.xlabel('Time (hours)')
plt.ylabel('Irradiance (lux)')
plt.legend()
plt.grid(True)
plt.xlim(48, 72)
plt.xticks(range(48, 72, 1), range(0, 24, 1))

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 22
#      16 labels = {
#      17     'rectangular_pulse': '00578_rectangular_pulse_588lux',
#      18     'rectangular_bursts': '19295_rectangular_bursts_200lux_burst800lux'
#      19 }
#      21 # Get the common time vector
# ---> 22 t = metrics['00578_rectangular_pulse_588lux']['time']
#      23 t_hours = t / 3600  # Convert seconds to hours
#      25 # Create a figure with three subplots
#
# KeyError: '00578_rectangular_pulse_588lux'
